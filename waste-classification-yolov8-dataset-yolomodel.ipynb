# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/ultralytics/yolov5 && %cd yolov5 && !pip install -r requirements.txt  # install dependencies

# %% [markdown]
# # Yaml
#
# train: /kaggle/input/garbage-detection/train/images
# val: /kaggle/input/garbage-detection/valid/images
#
# nc: 6
# names: ['BIODEGRADABLE', 'CARDBOARD', 'GLASS', 'METAL', 'PAPER', 'PLASTIC']

# %%
import shutil
shutil.copy('/kaggle/input/garbage-data/data.yaml', 'data.yaml')

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt')  # you can also try yolov8m.pt or yolov8n.pt

model.train(
    data='data.yaml',
    epochs=15,
    imgsz=640,
    batch=16,
    name='garbage-yolov8'
)

# %%
results = model.predict('/kaggle/input/garbage-data/YOLO-Waste-Detection-1/YOLO-Waste-Detection-1/test/images', save=True)

# %%
import cv2
import matplotlib.pyplot as plt

# Path to your image
image_path = "/kaggle/working/runs/detect/garbage-yolov82/00a6aeda-R_2700_jpg.rf.1797deb3cd3719c057a81a3442df4f26.jpg"

# Load image with OpenCV (BGR format)
image = cv2.imread(image_path)

# Convert BGR to RGB for displaying correctly with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Path to your image
image_path = "/kaggle/working/runs/detect/garbage-yolov82/0a0a1694-AluCan422_jpg.rf.39d2bcc1ba5405d0f78c2cbab54ade74.jpg"

# Load image with OpenCV (BGR format)
image = cv2.imread(image_path)

# Convert BGR to RGB for displaying correctly with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Path to your image
image_path = "/kaggle/working/runs/detect/garbage-yolov82/fff17199-R_219_jpg.rf.620ed52a6293a7260e170cdfb3620b1a.jpg"

# Load image with OpenCV (BGR format)
image = cv2.imread(image_path)

# Convert BGR to RGB for displaying correctly with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import os
import cv2
import matplotlib.pyplot as plt

def show_images_grid(images_dir, start_index=0, rows=4, cols=5):
    # Get all image filenames sorted
    image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    
    # Calculate total images to show
    total_images = rows * cols
    
    # Select slice of images based on start_index and total_images
    selected_files = image_files[start_index : start_index + total_images]
    
    plt.figure(figsize=(cols * 5, rows * 4))
    
    for idx, img_filename in enumerate(selected_files):
        img_path = os.path.join(images_dir, img_filename)
        image = cv2.imread(img_path)
        if image is None:
            continue
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        plt.subplot(rows, cols, idx + 1)
        plt.imshow(image_rgb)
        plt.axis('off')
        plt.title(img_filename, fontsize=8)
    
    plt.tight_layout()
    plt.show()

# Usage examples:
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=0)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=25)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=50)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=75)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=100)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=125)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=150)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=175)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=200)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=225)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=450)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=475)

# %%
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', start_index=500)

# %%
import os
import cv2
import matplotlib.pyplot as plt

def show_images_grid(images_dir, start_index=500, rows=4, cols=5, save_path=None):
    # Get all image filenames sorted
    image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    
    # Calculate total images to show
    total_images = rows * cols
    
    # Select slice of images based on start_index and total_images
    selected_files = image_files[start_index : start_index + total_images]
    
    plt.figure(figsize=(cols * 5, rows * 4))
    
    for idx, img_filename in enumerate(selected_files):
        img_path = os.path.join(images_dir, img_filename)
        image = cv2.imread(img_path)
        if image is None:
            continue
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        plt.subplot(rows, cols, idx + 1)
        plt.imshow(image_rgb)
        plt.axis('off')
        plt.title(img_filename, fontsize=8)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path)
        print(f"Saved grid image to {save_path}")
        
    plt.show()

# Example usage:
show_images_grid('/kaggle/working/runs/detect/garbage-yolov82', save_path='/kaggle/working/yolo_charts_grid.png')

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/kaggle/working/yolo11n.pt')

# %%
# Predict on an image
results = model('/kaggle/input/garbage-data/YOLO-Waste-Detection-1/YOLO-Waste-Detection-1/test/images/00a6aeda-R_2700_jpg.rf.1797deb3cd3719c057a81a3442df4f26.jpg')  # or a PIL Image / NumPy array

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load the model
model = YOLO('/kaggle/working/runs/detect/garbage-yolov8/weights/best.pt')

# Path to input image
image_path = "/kaggle/input/garbage-realworld/garbage/plastic1.png"

# Run inference
results = model(image_path)

# Results[0] contains boxes, labels, scores
res = results[0]

# Load image
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Define class names (43 total)
class_names = [
    "Aerosols", "Aluminum can", "Aluminum caps", "Cardboard", "Cellulose", "Ceramic",
    "Combined plastic", "Container for household chemicals", "Disposable tableware", "Electronics",
    "Foil", "Furniture", "Glass bottle", "Iron utensils", "Liquid", "Metal shavings",
    "Milk bottle", "Organic", "Paper bag", "Paper cups", "Paper shavings", "Paper",
    "Papier mache", "Plastic bag", "Plastic bottle", "Plastic can", "Plastic canister",
    "Plastic caps", "Plastic cup", "Plastic shaker", "Plastic shavings", "Plastic toys",
    "Postal packaging", "Printing industry", "Scrap metal", "Stretch film", "Tetra pack",
    "Textile", "Tin", "Unknown plastic", "Wood", "Zip plastic bag", "Ramen Cup"
]

# Draw boxes
for box in res.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])  # box coordinates
    cls_id = int(box.cls[0])               # class ID
    conf = float(box.conf[0])              # confidence
    label = f"{class_names[cls_id]} {conf:.2f}"
    
    # Draw rectangle and label
    cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(image_rgb, label, (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# Show image
plt.figure(figsize=(10, 8))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Predicted Bounding Boxes")
plt.show()
